# %%
# !nvidia-smi
# import torch
# print(torch.cuda.is_available())

# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %%
# %cd /content/drive/MyDrive
# !git clone https://github.com/VERNA990/speech-to-text-system.git
# !git config --global user.email "verenafonyuy11@gmail.com"
# !git config --global user.name "verna990"
# %cd /content/drive/MyDrive
#%cd /content/drive/MyDrive/speech-to-text-system
#!git checkout verna
# %ls
# !git branch
# !git pull --rebase origin verna

# !git pull origin verna
# Out:
# From https://github.com/VERNA990/speech-to-text-system
#  * branch            verna      -> FETCH_HEAD
# Already up to date.

# %%
# %cd ai-service/
# %ls
# %cat requirements.txt
# %uvicorn app.main:app --reload
# Out:
# app/  requirements.txt  speech-to-text.py
