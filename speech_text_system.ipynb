# %%
# !nvidia-smi
# import torch
# print(torch.cuda.is_available())

# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %%
# %cd /content/drive/MyDrive
# !git clone https://github.com/VERNA990/speech-to-text-system.git
# !git config --global user.email "verenafonyuy11@gmail.com"
# !git config --global user.name "verna990"
# %cd /content/drive/MyDrive
#%cd /content/drive/MyDrive/speech-to-text-system
#!git checkout verna
# %ls
# !git branch
#!git pull --rebase origin verna

# !git pull origin verna

# %%
# %cd ai-service/
# %ls drive/MyDrive/speech-to-text-system/ai-service/
# %cd drive/MyDrive/speech-to-text-system/ai-service/
# %ls

# %pip install -r requirements.txt
#%cat requirements.txt
# %pip install torch>=2.8.0 torchaudio>=2.8.0 --index-url https://download.pytorch.org/whl/cu121
# %pip install pyannote-audio
# %pip install torchvision --upgrade
# %pip freeze > drive/MyDrive/speech-to-text-system/ai-service/requirements.txt
# First install torch with the right CUDA version for Colab
# %pip install torch==2.12.0 torchaudio==2.11.0 torchvision --index-url https://download.pytorch.org/whl/cu121

# Then install everything else
# %pip install openai-whisper pyannote-audio fastapi uvicorn python-multipart
# !uvicorn app.main:app --reload
